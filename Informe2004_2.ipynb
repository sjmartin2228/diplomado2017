# %%
import pandas as pd

# %%
# !head AportesDiario_2004.csv
# Out:
# "head" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
pd.read_csv('AportesDiario_2004.csv', sep=';', decimal=',', thousands='.', skiprows=3)
# Out:
#       01/01/2004       ANTIOQUIA             A. SAN LORENZO   17,56  \
# 0     01/01/2004       ANTIOQUIA                 CONCEPCION    6.15
# 1     01/01/2004       ANTIOQUIA  DESV. EEPPM (NEC,PAJ,DOL)   11.43
# 2     01/01/2004       ANTIOQUIA                     GRANDE   18.65
# 3     01/01/2004       ANTIOQUIA                  GUADALUPE   11.28
# 4     01/01/2004       ANTIOQUIA                    GUATAPE   32.71
# 5     01/01/2004       ANTIOQUIA                     MIEL I   50.63
# 6     01/01/2004       ANTIOQUIA                       NARE   20.16
# 7     01/01/2004       ANTIOQUIA                   PORCE II   64.61
# 8     01/01/2004       ANTIOQUIA                 SAN CARLOS   12.80
# 9     01/01/2004       ANTIOQUIA                     TENCHE    1.81
# 10    01/01/2004          CARIBE                  SINU URRA  152.23
# 11    01/01/2004          CENTRO                BOGOTA N.R.    9.56
# 12    01/01/2004          CENTRO          MAGDALENA BETANIA  194.95
# ...
